# %% [markdown]
# ## CE9010: Introduction to Data Science
# ## Semester 2 2017/18
# ## Xavier Bresson
# ## ⚠ Student name:
# <br>
#
#
# ## Laboratory test 1: Supervised regression
# Instruction: Check the box with the right answer.<br>
#
# Grading: You will receive 1 point for each of the questions you answer correctly.<br>
# $ $

# %%
# Import libraries

# math library
import numpy as np

# visualization library
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png2x','pdf')
import matplotlib.pyplot as plt

# machine learning library
from sklearn.linear_model import LinearRegression

# 3d visualization
from mpl_toolkits.mplot3d import axes3d

# computational time
import time

# %% [markdown]
# # Problem 1: Supervised regression with one feature
# <hr>
# The data feature is $x$ and the data label/target is $y$.<br>

# %%
# import data with numpy
data = np.loadtxt('data/lab01_data1.txt', delimiter=',')
#print(data[:10,:])

# %% [markdown]
# ### Q1: What is the number $n$ of training data, and the dimension $d$ of each data?
#
# ☐ $n$=47, $d$=47 <br>
# ☐ $n$=2, $d$=47 <br>
# ☐ $n$=47, $d$=2 <br>
# ☐ $n$=2, $d$=2

# %%
#dataset is (feature, target) / (feature, feature, target)
#so only has one dimension in this case as there is only one feature and target
print(data.shape)
# Out:
# (47, 2)

# %% [markdown]
# ### Q2: What is the value of the predictive linear function $f_w(x)$ for $x=0.2$ with $w_0=0.2, w_1=-0.4$?
#
# ☐ $f$ = 0.24<br>
# ☐ $f$ = 0.06<br>
# ☐ $f$ = 0.48<br>
# ☐ $f$ = 0.12

# %%
#YOUR CODE HERE
n = data.shape[0]
x_train = data[:,0]
y_train = data[:,1]

# construct data matrix
X = np.ones([n,2]) 
X[:,1] = x_train

w = np.array([0.2,-0.4])[:,None] # [:,None] adds a singleton dimension

# predictive function definition
def f_pred(X,w):
    f = X.dot(w)
    return f

# Test predicitive function 
y_pred = f_pred(X,w)

print('Value:', np.array([[1,0.2]]).dot(w)[0,0])
print((w[0]+w[1]*0.2))
# Out:
# Value: 0.12
# [0.12]

# %% [markdown]
# ### Q3: What is the value of the mean square error (MSE) regression loss function $L(w)$ for $w_0=0.2, w_1=-0.4$?
#
# ☐ $L$ = 0.345<br>
# ☐ $L$ = 0.165<br>
# ☐ $L$ = 0.273<br>
# ☐ $L$ = 0.657

# %%
#YOUR CODE HERE
# loss function definition
def loss_mse(y_pred,y): 
    n = len(y)
    #YOUR CODE HERE
    loss = (1/n)*(y_pred-y).T.dot(y_pred-y)
    return loss


# Test loss function 
y = y_train[:,None] # label 
#print(y.shape)
y_pred = f_pred(X,w) # prediction
loss = loss_mse(y_pred,y)
print(loss)
# Out:
# [[0.27369978]]

# %% [markdown]
# ### Q4: What is the value of the gradient of the MSE regression loss function $\frac{\partial}{\partial w} L(w)$ for $w_0=0.2, w_1=-0.4$?
#
# ☐ $\frac{\partial}{\partial w} L$ = [-0.43,0.49]<br>
# ☐ $\frac{\partial}{\partial w} L$ = [-0.93,-0.49]<br>
# ☐ $\frac{\partial}{\partial w} L$ = [-0.27,-0.21]<br>
# ☐ $\frac{\partial}{\partial w} L$ = [-0.61,0.87]

# %%
#YOUR CODE HERE
def grad_loss(y_pred,y,X):
    n = len(y)
    grad = (2/n)*X.T.dot(y_pred-y)
    return grad


# Test grad function 
y_pred = f_pred(X,w)
grad = grad_loss(y_pred,y,X)
print(grad)
# Out:
# [[-0.93017149]
#  [-0.49330366]]

# %% [markdown]
# ### Q5: What is the value of the MSE regression loss function $L(w)$ after $200$ gradient descent iterations starting at $w_0=0.2, w_1=-0.4$ and selecting a learning rate $\tau=0.1$?
#
# ☐ $L$ = 0.013<br>
# ☐ $L$ = 0.023<br>
# ☐ $L$ = 0.008<br>
# ☐ $L$ = 0.045

# %%
#YOUR CODE HERE
def grad_desc(X, y , w_init=np.array([0,0])[:,None] ,tau=0.01, max_iter=500):

    L_iters = np.zeros([max_iter]) # record the loss values
    w_iters = np.zeros([max_iter,2]) # record the loss values
    w = w_init # initialization
    for i in range(max_iter): # loop over the iterations
        y_pred = f_pred(X,w) # linear predicition function 
        grad_f = grad_loss(y_pred,y,X) # gradient of the loss 
        w = w - tau * (2/n) * X.T.dot(X.dot(w)-y) #YOUR CODE HERE
        L_iters[i] = loss_mse(y_pred,y) # save the current loss value 
        w_iters[i,:] = w[0],w[1] # save the current w value 
        
    return w, L_iters, w_iters


w_init = np.array([0.2,-0.4])[:,None]
tau = 0.1
max_iter = 200
w, L_iters, w_iters = grad_desc(X,y,w_init,tau,max_iter)
print(L_iters[-1])
x_pred = np.linspace(0,1,100) #YOUR CODE HERE
y_pred = w[0] + w[1]* x_pred

plt.figure(3)
plt.scatter(x_train, y_train, s=30, c='r', marker='x', linewidths=1)
plt.plot(x_pred, y_pred,label='gradient descent optimization'.format(i=1))
plt.legend(loc='best')
plt.title('Training data')
plt.xlabel('Population size (x 10k)')
plt.ylabel('Profit $(x 10k)')
plt.show()
# Out:
# 0.013081425021531335

# %% [markdown]
# ### Q6: What is the value of the MSE regression loss function $L(w)$ computed with scikit-learn?
#
# ☐ $L$ = 0.004<br>
# ☐ $L$ = 0.006<br>
# ☐ $L$ = 0.008<br>
# ☐ $L$ = 0.013

# %%
#YOUR CODE HERE
lin_reg_sklearn = LinearRegression()
lin_reg_sklearn.fit(x_train[:,None], y_train) #YOUR CODE HERE # learn the model parameters 

w_sklearn = np.zeros([2,1])
w_sklearn[0,0] = lin_reg_sklearn.intercept_
w_sklearn[1,0] = lin_reg_sklearn.coef_
print('w_sklearn=', w_sklearn)

loss_sklearn = loss_mse(f_pred(X,w_sklearn),y_train[:,None])
print('loss sklearn=',loss_sklearn)
print('loss gradient descent=',L_iters[-1]) 

y_pred_sklearn = w_sklearn[0] + w_sklearn[1]* x_pred

plt.figure(3)
plt.scatter(x_train, y_train, s=30, c='r', marker='x', linewidths=1)
plt.plot(x_pred, y_pred,label='gradient descent optimization'.format(i=1))
plt.plot(x_pred, y_pred_sklearn,label='Scikit-learn optimization'.format(i=2))
plt.legend(loc='best')
plt.title('Training data')
plt.xlabel('Population size (x 10k)')
plt.ylabel('Profit $(x 10k)')
plt.show()
# Out:
# w_sklearn= [[0.10183086]
#  [0.86069912]]
# loss sklearn= [[0.00840311]]
# loss gradient descent= 0.013081425021531335

# %% [markdown]
# ### Q7: What is the value of the predictive linear function $f_w(x)$ for $x=0.2$ with the parameters $w_0,w_1$ computed with scikit-learn?
#
# ☐ $f$ = 0.42<br>
# ☐ $f$ = 0.11<br>
# ☐ $f$ = 0.27<br>
# ☐ $f$ = 0.34

# %%
#YOUR CODE HERE
print('Value:', np.array([[1,0.2]]).dot(w_sklearn)[0,0])
print((w_sklearn[0]+w_sklearn[1]*0.2))
# Out:
# Value: 0.27397068397400526
# [0.27397068]

# %% [markdown]
# # Problem 2: Supervised regression with two features
# <hr>
# The data features are $x_{(1)},x_{(2)}$ and the data label/target is $y$.<br>

# %%
# import data with numpy
data = np.loadtxt('data/lab01_data2.txt', delimiter=',')
#print(data[:10,:])

# %% [markdown]
# ### Q8: What is the value of the predictive linear function $f_w(x)$ for $x_{(1)}=0.2,x_{(2)}=0.6$ with $w_0=0.2, w_1=-0.4, w_2=0.1$?
#
# ☐ $f$ = 0.18<br>
# ☐ $f$ = 0.22<br>
# ☐ $f$ = 0.35<br>
# ☐ $f$ = 0.56

# %%
#YOUR CODE HERE
n = data.shape[0]
x_train = data[:,0:2]
y_train = data[:,2]

# construct data matrix
X = np.ones([n,3]) 
X[:,1:3] = x_train

w = np.array([0.2,-0.4, 0.1])[:,None] # [:,None] adds a singleton dimension

# predictive function definition
def f_pred(X,w):
    f = X.dot(w)
    return f

# Test predicitive function 
y_pred = f_pred(X,w)

print('Value:', np.array([[1,0.2, 0.6]]).dot(w)[0,0])
print((w[0]+w[1]*0.2+w[2]*0.6))
# Out:
# Value: 0.18
# [0.18]
# 0.2

# %% [markdown]
# ### Q9: What is the value of the MSE regression loss function $L(w)$ after $200$ gradient descent iterations starting at $w_0=0.2, w_1=-0.4, w_2=0.1$ and selecting a learning rate $\tau=0.1$?
#
# ☐ $L$ = 0.023<br>
# ☐ $L$ = 0.029<br>
# ☐ $L$ = 0.014<br>
# ☐ $L$ = 0.010

# %%
#YOUR CODE HERE
# loss function definition
def loss_mse(y_pred,y): 
    n = len(y)
    #YOUR CODE HERE
    loss = (1/n)*(y_pred-y).T.dot(y_pred-y)
    return loss

def grad_loss(y_pred,y,X):
    n = len(y)
    grad = (2/n)*X.T.dot(y_pred-y)
    return grad

def grad_desc(X, y , w_init=np.array([0,0,0])[:,None] ,tau=0.01, max_iter=500):

    L_iters = np.zeros([max_iter]) # record the loss values
    w_iters = np.zeros([max_iter,3]) # record the loss values
    w = w_init # initialization
    for i in range(max_iter): # loop over the iterations
        y_pred = f_pred(X,w) # linear predicition function 
        grad_f = grad_loss(y_pred,y,X) # gradient of the loss 
        w = w - tau * grad_f #YOUR CODE HERE
        L_iters[i] = loss_mse(y_pred,y) # save the current loss value 
        w_iters[i,:] = w[0],w[1],w[2] # save the current w value 
        
    return w, L_iters, w_iters

w_init = np.array([0.2,-0.4,0.1])[:,None]
tau = 0.1
max_iter = 200
w, L_iters, w_iters = grad_desc(X,y,w_init,tau,max_iter)
print(L_iters[-1])
# Out:
# 0.014101160791508591

# %% [markdown]
# # Problem 3: Supervised regression with two features and the MAE loss
# <hr>
# The data features are $x_{(1)},x_{(2)}$ and the data label/target is $y$.<br>
#
# We consider a new loss defined as
# $$
# L(w)=\frac{1}{n} \sum_{i=1}^n \ \big| \ f_w(x_i) – y_i \ \big|
# $$
# It is called the mean absolute error (MAE) loss, a.k.a. L1 loss.

# %% [markdown]
# ### Q10: What is the value of the MAE regression loss function $L(w)$ after $200$ gradient descent iterations starting at $w_0=0.2, w_1=-0.4, w_2=0.1$ and selecting a learning rate $\tau=0.1$?
#
# ☐ $L$ = 0.014 <br>
# ☐ $L$ = 0.038<br>
# ☐ $L$ = 0.051<br>
# ☐ $L$ = 0.074

# %%
#YOUR CODE HERE
n = data.shape[0]
x_train = data[:,0:2]
y_train = data[:,2]

# construct data matrix
X = np.ones([n,3]) 
X[:,1:3] = x_train

w = np.array([0.2,-0.4, 0.1])[:,None] # [:,None] adds a singleton dimension

# predictive function definition
def f_pred(X,w):
    f = X.dot(w)
    return f

# loss function definition
def loss_mse(y_pred,y): 
    n = len(y)
    #YOUR CODE HERE
    loss = (1/n)*(np.abs(y_pred-y)).T.dot(np.ones([n,1]))
    return loss

def grad_loss(y_pred,y,X):
    n = len(y)
    grad = (2/n)*abs(X.T).dot(np.ones([n,1]))
    return grad

def grad_desc(X, y , w_init=np.array([0,0,0])[:,None] ,tau=0.01, max_iter=500):

    L_iters = np.zeros([max_iter]) # record the loss values
    w_iters = np.zeros([max_iter,3]) # record the loss values
    w = w_init # initialization
    for i in range(max_iter): # loop over the iterations
        y_pred = f_pred(X,w) # linear predicition function 
        grad_f = grad_loss(y_pred,y,X) # gradient of the loss 
        w = w - tau * grad_f #YOUR CODE HERE
        L_iters[i] = loss_mse(y_pred,y) # save the current loss value 
        w_iters[i,:] = w[0],w[1],w[2] # save the current w value 
        
    return w, L_iters, w_iters

w_init = np.array([0.2,-0.4,0.1])[:,None]
tau = 0.1
max_iter = 200
w, L_iters, w_iters = grad_desc(X,y,w_init,tau,max_iter)
print(L_iters[-1])
# Out:
# 64.14624256339326
